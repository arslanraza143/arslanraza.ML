# %% [markdown]
# # h1

# %% [markdown]
# ## this is 2nd headin

# %% [markdown]
# ### this is 3rd heading

# %% [markdown]
# #### this is 4th heading

# %% [markdown]
# ##### this is 5th heading

# %% [markdown]
# ###### this is 6th

# %% [markdown]
# bold **Artificial Intelligence**

# %% [markdown]
# italic *this is italic command*

# %% [markdown]
# unordered list
# - stop one
# - steop 2
# - step e

# %% [markdown]
# 1. step one
# 2. step two
# 3. step 3

# %% [markdown]
# link (https://github.com/arslanraza143)

# %% [markdown]
# ![images - Copy.jpg](<attachment:images - Copy.jpg>)

# %% [markdown]
# | Name | | Age | | Class |
